# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import joblib as job

# %%
df1 = pd.read_csv("temp.csv")

# %%
df1.sample(frac=1)
# Out:
#       Unnamed: 0                                   name  year  selling_price  \
# 5599        5599       Volkswagen Polo 1.5 TDI Highline  2015         550000
# 4083        4083                       BMW X6 xDrive30d  2013        3750000
# 5589        5589                   Ford Figo Diesel ZXI  2011         229999
# 7923        7923    Maruti Swift LDI SP Limited Edition  2015         500000
# 6237        6237          Chevrolet Enjoy 1.3 TCDi LS 7  2016         420000
# ...          ...                                    ...   ...            ...
# 2964        2964   Skoda Rapid 1.6 MPI AT Ambition BSIV  2019         835000
# 5774        5774    Toyota Innova Crysta 2.4 VX MT BSIV  2018        1938000
# 7283        7283  Hyundai i20 2015-2017 Sportz 1.4 CRDi  2014         484999
# 6256        6256                   Maruti Alto LX BSIII  2005         110000
# 7368        7368                    Mahindra Marazzo M8  2019        1450000
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8128 non-null   int64
#  1   name           8128 non-null   object
#  2   year           8128 non-null   int64
#  3   selling_price  8128 non-null   int64
#  4   km_driven      8128 non-null   int64
#  5   fuel           8128 non-null   object
#  6   seller_type    8128 non-null   object
#  7   transmission   8128 non-null   object
#  8   owner          8128 non-null   object
#  9   mileage        8128 non-null   float64
#  10  engine         8128 non-null   int64
#  11  max_power      8127 non-null   float64
#  12  torque         8128 non-null   object
#  13  seats          8128 non-null   float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 889.1+ KB

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        1
# torque           0
# seats            0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8128 non-null   int64
#  1   name           8128 non-null   object
#  2   year           8128 non-null   int64
#  3   selling_price  8128 non-null   int64
#  4   km_driven      8128 non-null   int64
#  5   fuel           8128 non-null   object
#  6   seller_type    8128 non-null   object
#  7   transmission   8128 non-null   object
#  8   owner          8128 non-null   object
#  9   mileage        8128 non-null   float64
#  10  engine         8128 non-null   int64
#  11  max_power      8127 non-null   float64
#  12  torque         8128 non-null   object
#  13  seats          8128 non-null   float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 889.1+ KB

# %%
df1.describe()
# Out:
#         Unnamed: 0         year  selling_price     km_driven      mileage  \
# count  8128.000000  8128.000000   8.128000e+03  8.128000e+03  8128.000000
# mean   4063.500000  2013.804011   6.382718e+05  6.981951e+04    19.404678
# std    2346.495827     4.044249   8.062534e+05  5.655055e+04     3.982769
# min       0.000000  1983.000000   2.999900e+04  1.000000e+00     0.000000
# 25%    2031.750000  2011.000000   2.549990e+05  3.500000e+04    16.800000
# 50%    4063.500000  2015.000000   4.500000e+05  6.000000e+04    19.100000
# 75%    6095.250000  2017.000000   6.750000e+05  9.800000e+04    22.277500
# max    8127.000000  2020.000000   1.000000e+07  2.360457e+06    42.000000
#
#            engine    max_power        seats
# count  8128.00000  8127.000000  8128.000000
# mean   1452.89813    91.054482     5.405389
# std     498.19672    35.457065     0.948874
# min     624.00000     0.000000     2.000000
# 25%    1197.00000    68.100000     5.000000
# ...

# %%
mean = int(df1['seats'].mean())
df1['mileage'].fillna(df1['mileage'].mode()[0], inplace=True)
df1['torque'].fillna(df1['torque'].mode()[0], inplace=True)
df1['max_power'].fillna(df1['max_power'].mode()[0], inplace=True)
df1['engine'].fillna(df1['engine'].mode()[0], inplace=True)
df1['seats'].fillna(mean, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df_test = df1

# %%
df_test.corr()
# Out:
# C:\Users\ASUS User\AppData\Local\Temp\ipykernel_25572\2476447169.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_test.corr()
#                Unnamed: 0      year  selling_price  km_driven   mileage  \
# Unnamed: 0       1.000000  0.001276      -0.011219   0.008766  0.028422
# year             0.001276  1.000000       0.414092  -0.418006  0.315896
# selling_price   -0.011219  0.414092       1.000000  -0.225534 -0.123623
# km_driven        0.008766 -0.418006      -0.225534   1.000000 -0.172792
# mileage          0.028422  0.315896      -0.123623  -0.172792  1.000000
# engine          -0.010151  0.035851       0.458345   0.198911 -0.572883
# max_power       -0.000822  0.233949       0.749350  -0.042958 -0.370287
# seats           -0.012748  0.010222       0.047135   0.219860 -0.449315
#
# ...

# %%
df1.agg(['count', 'size', 'nunique'])
# Out:
#          Unnamed: 0  name  year  selling_price  km_driven  fuel  seller_type  \
# count          8128  8128  8128           8128       8128  8128         8128
# size           8128  8128  8128           8128       8128  8128         8128
# nunique        8128  2058    29            677        921     4            3
#
#          transmission  owner  mileage  engine  max_power  torque  seats
# count            8128   8128     8128    8128       8128    8128   8128
# size             8128   8128     8128    8128       8128    8128   8128
# nunique             2      5      381     121        319     441      9

# %%
df1['seats']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 8123    5.0
# 8124    5.0
# 8125    5.0
# 8126    5.0
# 8127    5.0
# Name: seats, Length: 8128, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets


plt.scatter(df_test['selling_price'],df_test['km_driven'])

# %%
plt.scatter(df_test['selling_price'],df_test['max_power'])

# %%
df_test.agg(['count', 'size', 'nunique'])
# Out:
#          Unnamed: 0  name  year  selling_price  km_driven  fuel  seller_type  \
# count          8128  8128  8128           8128       8128  8128         8128
# size           8128  8128  8128           8128       8128  8128         8128
# nunique        8128  2058    29            677        921     4            3
#
#          transmission  owner  mileage  engine  max_power  torque  seats
# count            8128   8128     8128    8128       8128    8128   8128
# size             8128   8128     8128    8128       8128    8128   8128
# nunique             2      5      381     121        319     441      9

# %%
predict = 'selling_price'
X = df_test.drop(['Unnamed: 0', 'name', predict,'torque','seats'], axis=1)
y = df_test[predict]
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split
X_train, X_test, ytrain, ytest = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
# import category encoders

import category_encoders as ce

# %%
# encode variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=['fuel', 'seller_type', 'transmission','mileage','owner'])


X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)

# %%
X_train.corr()
# Out:
#                   year  km_driven      fuel  seller_type  transmission  \
# year          1.000000  -0.386325 -0.073739     0.233350      0.239607
# km_driven    -0.386325   1.000000 -0.220272    -0.187431     -0.184390
# fuel         -0.073739  -0.220272  1.000000    -0.045709      0.001592
# seller_type   0.233350  -0.187431 -0.045709     1.000000      0.362078
# transmission  0.239607  -0.184390  0.001592     0.362078      1.000000
# owner        -0.504675   0.263287  0.014948    -0.206639     -0.131515
# mileage       0.053333  -0.026561 -0.035581     0.079957      0.192908
# engine        0.038928   0.190246 -0.490244     0.138138      0.287104
# max_power     0.240952  -0.044481 -0.308563     0.302427      0.548927
#
#                  owner   mileage    engine  max_power
# year         -0.504675  0.053333  0.038928   0.240952
# km_driven     0.263287 -0.026561  0.190246  -0.044481
# fuel          0.014948 -0.035581 -0.490244  -0.308563
# ...

# %%
X_test
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 1971  2004     110000     2            1             1      3     17.0
# 4664  2014     291977     1            1             1      1     90.0
# 5448  2016      70000     1            1             1      1    185.0
# 3333  2006     120000     2            1             1      2    149.0
# 2316  2013      69000     1            1             1      2    156.0
# ...    ...        ...   ...          ...           ...    ...      ...
# 4169  2017      21000     2            1             1      1     39.0
# 2691  2013      60000     2            1             1      2    101.0
# 5082  2004     100000     1            1             1      4     93.0
# 2662  2012      70000     1            1             1      2     80.0
# 3245  2017      58000     2            3             2      1    123.0
#
#       engine  max_power
# 1971    1493     100.00
# 4664    2179     138.10
# 5448    1248      73.94
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 10, random_state = 42)
# Train the model on training data
rf.fit(X_train,ytrain );
job.dump(rf ,'model.sav')
# Out:
# ['model.sav']

# %% [markdown]
# col_names =["name","year","selling_price","km_driven","fuel","seller_type","transmission","owner","mileage","engine","max_power","torque","seats"]

# %% [markdown]
# predict = 'selling_price'
# x = df_test.drop([predict,'name','fuel','seller_type','transmission','owner','mileage','engine','max_power','torque'], axis=1)
#
# y = df_test[predict]
# from sklearn.model_selection import train_test_split
# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=44)
# from sklearn.tree import DecisionTreeRegressor
# model = DecisionTreeRegressor(random_state=44)
# model.fit(xtrain, ytrain)

# %%
predictions = rf.predict(X_test)

# %%
error = abs(predictions - ytest)
res=round(np.mean(error), 2)
res
# Out:
# 75356.01

# %%
mape = 100 * (error / ytest)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 83.66 %.

# %%
from sklearn.metrics import r2_score, accuracy_score
r2_score(ytest, predictions)
# Out:
# 0.9526649469406807
